# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
independ=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independ
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
depend=dataset[['charges']]
depend
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independ,depend,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor
param={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best','random'],'max_features':['sqrt','log2']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(),param,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
res=grid.cv_results_
print("The R_Score value for bet parameter{}:".format(grid.best_params_))
# Out:
# The R_Score value for bet parameter{'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(res)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.030738      0.014298         0.002907        0.001468
# 1        0.009161      0.009602         0.003497        0.000845
# 2        0.005762      0.001318         0.002307        0.000511
# 3        0.003461      0.001152         0.002905        0.002036
# 4        0.002459      0.002090         0.003144        0.004778
# 5        0.005945      0.003346         0.004260        0.001258
# 6        0.005160      0.000887         0.003601        0.000919
# 7        0.003465      0.002001         0.002982        0.002784
# 8        0.014129      0.003583         0.003025        0.000515
# 9        0.010853      0.001959         0.003435        0.001958
# 10       0.012336      0.001751         0.002062        0.001155
# 11       0.011804      0.002096         0.003164        0.000648
# 12       0.005824      0.002373         0.003380        0.001137
# 13       0.006652      0.001446         0.003145        0.001984
# 14       0.005145      0.001582         0.002742        0.001692
# 15       0.005500      0.004086         0.004394        0.003094
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.629470
# 1   {'criterion': 'squared_error', 'max_features':...           0.742367
# 2   {'criterion': 'squared_error', 'max_features':...           0.725267
# 3   {'criterion': 'squared_error', 'max_features':...           0.713615
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.776561
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.719360
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.757867
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.773831
# 8   {'criterion': 'absolute_error', 'max_features'...           0.679337
# 9   {'criterion': 'absolute_error', 'max_features'...           0.764419
# 10  {'criterion': 'absolute_error', 'max_features'...           0.600226
# 11  {'criterion': 'absolute_error', 'max_features'...           0.615125
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.798253
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.710312
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.513769
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.776213
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.593875           0.567531           0.516321
# 1            0.484226           0.633070           0.514088
# 2            0.401877           0.577353           0.578352
# 3            0.604825           0.532729           0.609706
# 4            0.438325           0.450009           0.610451
# 5            0.599705           0.655177           0.652662
# 6            0.617932           0.655536           0.661433
# 7            0.540336           0.628582           0.516235
# 8            0.688955           0.574838           0.632274
# 9            0.443021           0.508709           0.738180
# 10           0.624000           0.622501           0.615430
# 11           0.582889           0.695614           0.455887
# 12           0.553715           0.759205           0.664334
# 13           0.521693           0.664511           0.505218
# 14           0.631794           0.567727           0.679368
# 15           0.639868           0.548712           0.615452
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.544614         0.570362        0.039085               15
# 1            0.611300         0.597010        0.091902               11
# 2            0.476070         0.551784        0.109234               16
# 3            0.650883         0.622351        0.059401                5
# 4            0.660401         0.587149        0.128640               13
# 5            0.630284         0.651438        0.039377                3
# 6            0.637175         0.665989        0.048397                2
# 7            0.526696         0.597136        0.096895               10
# 8            0.638615         0.642804        0.040527                4
# 9            0.625595         0.615985        0.125285                7
# 10           0.553307         0.603093        0.026279                9
# 11           0.593568         0.588617        0.077234               12
# 12           0.605787         0.676259        0.091530                1
# 13           0.656632         0.611673        0.082428                8
# 14           0.538202         0.586172        0.061074               14
# 15           0.531056         0.622260        0.086931                6

# %%
Age=input("Age:")
BMI=input("BMI:")
children=input("Children:")
sex=input("Male 0 or1:")
smoke=input("Smoke yes 0 or 1:")
# Out:
# Age: 33
# BMI: 50
# Children: 1
# Male 0 or1: 1
# Smoke yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[Age,BMI,children,sex,smoke]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[44501.]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
