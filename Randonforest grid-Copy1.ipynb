# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
independ=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independ
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
depend=dataset[['charges']]
depend
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
param={'criterion':('squared_error', 'absolute_error', 'friedman_mse', 'poisson'),'max_features':('auto','sqrt','log2'),'n_estimators':(10,100)}

# %%
grid=GridSearchCV(RandomForestRegressor(),param,refit=True,verbose=3,n_jobs=-1)
grid.fit(independ,depend)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 13 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81519747 0.82862593 0.80808215 0.82826982
#         nan        nan 0.80991242 0.83310749 0.81890581 0.82903416
#         nan        nan 0.81284924 0.82911329 0.81198055 0.82936057
#         nan        nan 0.80897588 0.82805471 0.80344548 0.83031429]
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ('squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'),
#                          'max_features': ('auto', 'sqrt', 'log2'),
#                          'n_estimators': (10, 100)},
#              verbose=3)

# %%
result=grid.cv_results_
print("The R score value the for best parameter {}:".format(grid.best_params_))
# Out:
# The R score value the for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004838      0.006302         0.000000        0.000000
# 1        0.005299      0.004136         0.000000        0.000000
# 2        0.070141      0.019039         0.015931        0.012116
# 3        2.836390      0.198302         0.167814        0.027848
# 4        0.332477      0.037799         0.069235        0.029193
# 5        3.241368      0.060333         0.106040        0.045130
# 6        0.009234      0.005869         0.000000        0.000000
# 7        0.021303      0.023073         0.000000        0.000000
# 8        1.265520      0.123591         0.041984        0.019353
# 9       12.275919      0.254492         0.169923        0.093321
# 10       1.310951      0.173061         0.056958        0.031366
# 11      12.347544      0.337977         0.165066        0.066017
# 12       0.005618      0.005559         0.000000        0.000000
# 13       0.012757      0.012086         0.000000        0.000000
# 14       0.551618      0.050234         0.067918        0.031586
# 15       3.874051      0.093080         0.153755        0.020301
# 16       0.432053      0.079848         0.070485        0.020980
# 17       3.331292      0.092528         0.205982        0.051463
# 18       0.015190      0.013493         0.000000        0.000000
# 19       0.025596      0.022461         0.000000        0.000000
# 20       0.677440      0.055202         0.055905        0.028269
# 21       4.483865      0.054301         0.153142        0.035951
# 22       0.477167      0.126676         0.030067        0.012479
# 23       3.670956      0.665498         0.087253        0.032084
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               auto                  10
# 1    squared_error               auto                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               auto                  10
# 7   absolute_error               auto                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12    friedman_mse               auto                  10
# 13    friedman_mse               auto                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18         poisson               auto                  10
# 19         poisson               auto                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.829804
# 3   {'criterion': 'squared_error', 'max_features':...           0.855225
# 4   {'criterion': 'squared_error', 'max_features':...           0.845591
# 5   {'criterion': 'squared_error', 'max_features':...           0.851976
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.842248
# 9   {'criterion': 'absolute_error', 'max_features'...           0.857606
# 10  {'criterion': 'absolute_error', 'max_features'...           0.827710
# 11  {'criterion': 'absolute_error', 'max_features'...           0.856404
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.840382
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.853901
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.830649
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.857811
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.830649
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.854536
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.847336
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.852889
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.764890           0.836597           0.807255
# 3            0.777758           0.848955           0.822120
# 4            0.763852           0.821174           0.798379
# 5            0.777849           0.854655           0.823185
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.756200           0.824182           0.806287
# 9            0.776982           0.858450           0.829479
# 10           0.767047           0.853616           0.811242
# 11           0.772001           0.853283           0.822857
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.749856           0.846462           0.813848
# 15           0.773301           0.852021           0.826922
# 16           0.762808           0.846343           0.814168
# 17           0.777496           0.852647           0.819856
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.747541           0.847189           0.810207
# 21           0.774425           0.854526           0.823836
# 22           0.746708           0.810596           0.793500
# 23           0.776671           0.853847           0.827600
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.837440         0.815197        0.027422               10
# 3            0.839071         0.828626        0.027784                6
# 4            0.811415         0.808082        0.026981               15
# 5            0.833684         0.828270        0.027769                7
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.820645         0.809912        0.029198               13
# 9            0.843020         0.833107        0.030013                1
# 10           0.834914         0.818906        0.029280                9
# 11           0.840627         0.829034        0.030862                5
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.813699         0.812849        0.034228               11
# 15           0.839422         0.829113        0.029548                4
# 16           0.805936         0.811981        0.028244               12
# 17           0.838994         0.829361        0.029068                3
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.809294         0.808976        0.033781               14
# 21           0.832950         0.828055        0.029393                8
# 22           0.819088         0.803445        0.033287               16
# 23           0.840564         0.830314        0.028473                2

# %%
Age=input("Age:")
BMI=input("BMI:")
children=input("Children:")
sex_male=input("Sex male 0 or 1:")
smoke_yes=input("Smoke yes 0 or 1:")
# Out:
# Age: 33
# BMI: 50
# Children: 1
# Sex male 0 or 1: 1
# Smoke yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[Age,BMI,children,sex_male,smoke_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[42431.05]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
